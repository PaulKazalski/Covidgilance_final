# %%
import pandas as pd

# %%
df1 = pd.read_excel('./Resources/2020 County Health Rankings Data2.xlsx')
df2 = pd.read_excel('./Covid-19/Resources/worldmeterUS_cleaned.xlsx')
df4 = pd.read_csv('./Covid-19/Resources/US_newcases.csv')

# %%
df1.drop('TotalCases',axis=1, inplace=True)
df1.drop('TotalDeaths',axis=1, inplace=True)

# %%
df1.count()
# Out:
# FIPS                                   3109
# State                                  3109
# County                                 3109
# Length of Life Quartile                3108
#  Quality of Life Quartile              3108
#  Health Behaviors Quartile             3108
# Clinical Care Quartile                 3108
#  Social & Economic Factors Quartile    3108
# Physical Environment Quartile          3108
# Average Quartile                       3056
# State rank                             3109
# county modifier                        3056
# overall county rank                    3056
# TotalCases                              855
# TotalDeaths                             855
# dtype: int64

# %%
df1
# Out:
#        FIPS    State      County Length of Life Quartile  \
# 0      1001  Alabama     Autauga                       1
# 1      1003  Alabama     Baldwin                       1
# 2      1005  Alabama     Barbour                       2
# 3      1007  Alabama        Bibb                       3
# 4      1009  Alabama      Blount                       3
# ...     ...      ...         ...                     ...
# 3104  56037  Wyoming  Sweetwater                       4
# 3105  56039  Wyoming       Teton                       1
# 3106  56041  Wyoming       Uinta                       3
# 3107  56043  Wyoming    Washakie                       2
# 3108  56045  Wyoming      Weston                       1
#
#       Quality of Life Quartile  Health Behaviors Quartile  \
# 0                            1                          1
# 1                            1                          1
# 2                            4                          4
# 3                            1                          2
# 4                            1                          1
# ...                        ...                        ...
# 3104                         4                          4
# 3105                         1                          1
# 3106                         4                          4
# 3107                         3                          2
# 3108                         2                          3
#
#      Clinical Care Quartile  Social & Economic Factors Quartile  \
# 0                         1                                   1
# 1                         1                                   1
# 2                         3                                   4
# 3                         2                                   3
# 4                         3                                   1
# ...                     ...                                 ...
# 3104                      3                                   3
# 3105                      1                                   1
# 3106                      3                                   4
# 3107                      4                                   3
# 3108                      2                                   2
#
#      Physical Environment Quartile  Average Quartile  State rank  \
# 0                                4          1.500000           1
# 1                                1          1.000000           1
# 2                                2          3.166667           1
# 3                                2          2.166667           1
# 4                                3          2.000000           1
# ...                            ...               ...         ...
# 3104                             4          3.666667           5
# 3105                             3          1.333333           5
# 3106                             4          3.666667           5
# 3107                             1          2.500000           5
# 3108                             2          2.000000           5
#
#       county modifier  overall county rank
# 0                 1.0                  2.0
# 1                 2.0                  3.0
# 2                -1.0                  0.0
# 3                 0.0                  1.0
# 4                 1.0                  2.0
# ...               ...                  ...
# 3104             -1.0                  4.0
# 3105              1.0                  6.0
# 3106             -1.0                  4.0
# 3107              0.0                  5.0
# 3108              1.0                  6.0
#
# [3109 rows x 13 columns]

# %%
df2.drop('Unnamed: 0', axis=1, inplace=True)
df2.drop(0, axis=0, inplace=True)

# %%
df2.rename(columns={'USAState':'State'}, inplace=True)

# %%
df2.count()
# Out:
# State          63
# TotalCases     63
# TotalDeaths    61
# dtype: int64

# %%
df3 = df1.merge(df2, on='State')

# %%
df3
# Out:
#        FIPS    State      County Length of Life Quartile  \
# 0      1001  Alabama     Autauga                       1
# 1      1003  Alabama     Baldwin                       1
# 2      1005  Alabama     Barbour                       2
# 3      1007  Alabama        Bibb                       3
# 4      1009  Alabama      Blount                       3
# ...     ...      ...         ...                     ...
# 3102  56037  Wyoming  Sweetwater                       4
# 3103  56039  Wyoming       Teton                       1
# 3104  56041  Wyoming       Uinta                       3
# 3105  56043  Wyoming    Washakie                       2
# 3106  56045  Wyoming      Weston                       1
#
#       Quality of Life Quartile  Health Behaviors Quartile  \
# 0                            1                          1
# 1                            1                          1
# 2                            4                          4
# 3                            1                          2
# 4                            1                          1
# ...                        ...                        ...
# 3102                         4                          4
# 3103                         1                          1
# 3104                         4                          4
# 3105                         3                          2
# 3106                         2                          3
#
#      Clinical Care Quartile  Social & Economic Factors Quartile  \
# 0                         1                                   1
# 1                         1                                   1
# 2                         3                                   4
# 3                         2                                   3
# 4                         3                                   1
# ...                     ...                                 ...
# 3102                      3                                   3
# 3103                      1                                   1
# 3104                      3                                   4
# 3105                      4                                   3
# 3106                      2                                   2
#
#      Physical Environment Quartile  Average Quartile  State rank  \
# 0                                4          1.500000           1
# 1                                1          1.000000           1
# 2                                2          3.166667           1
# 3                                2          2.166667           1
# 4                                3          2.000000           1
# ...                            ...               ...         ...
# 3102                             4          3.666667           5
# 3103                             3          1.333333           5
# 3104                             4          3.666667           5
# 3105                             1          2.500000           5
# 3106                             2          2.000000           5
#
#       county modifier  overall county rank  TotalCases_x  TotalDeaths_x  \
# 0                 1.0                  2.0        8120.0          310.0
# 1                 2.0                  3.0        8120.0          310.0
# 2                -1.0                  0.0        8120.0          310.0
# 3                 0.0                  1.0        8120.0          310.0
# 4                 1.0                  2.0        8120.0          310.0
# ...               ...                  ...           ...            ...
# 3102             -1.0                  4.0           NaN            NaN
# 3103              1.0                  6.0           NaN            NaN
# 3104             -1.0                  4.0           NaN            NaN
# 3105              0.0                  5.0           NaN            NaN
# 3106              1.0                  6.0           NaN            NaN
#
#       TotalCases_y  TotalDeaths_y
# 0             8120          310.0
# 1             8120          310.0
# 2             8120          310.0
# 3             8120          310.0
# 4             8120          310.0
# ...            ...            ...
# 3102           596            7.0
# 3103           596            7.0
# 3104           596            7.0
# 3105           596            7.0
# 3106           596            7.0
#
# [3107 rows x 17 columns]

# %%
df3.count()
# Out:
# FIPS                                   3107
# State                                  3107
# County                                 3107
# Length of Life Quartile                3107
#  Quality of Life Quartile              3107
#  Health Behaviors Quartile             3107
# Clinical Care Quartile                 3107
#  Social & Economic Factors Quartile    3107
# Physical Environment Quartile          3107
# Average Quartile                       3054
# State rank                             3107
# county modifier                        3054
# overall county rank                    3054
# TotalCases_x                            853
# TotalDeaths_x                           853
# TotalCases_y                           3107
# TotalDeaths_y                          3107
# dtype: int64

# %%
df3.drop('TotalCases_x', axis=1, inplace=True)
df3.drop('TotalDeaths_x', axis=1, inplace=True)
df3.rename(columns={'TotalCases_y':'TotalCases', 'TotalDeaths_y ':'TotalDeaths'}, inplace=True)

# %%
df3
# Out:
#        FIPS    State      County Length of Life Quartile  \
# 0      1001  Alabama     Autauga                       1
# 1      1003  Alabama     Baldwin                       1
# 2      1005  Alabama     Barbour                       2
# 3      1007  Alabama        Bibb                       3
# 4      1009  Alabama      Blount                       3
# ...     ...      ...         ...                     ...
# 3102  56037  Wyoming  Sweetwater                       4
# 3103  56039  Wyoming       Teton                       1
# 3104  56041  Wyoming       Uinta                       3
# 3105  56043  Wyoming    Washakie                       2
# 3106  56045  Wyoming      Weston                       1
#
#       Quality of Life Quartile  Health Behaviors Quartile  \
# 0                            1                          1
# 1                            1                          1
# 2                            4                          4
# 3                            1                          2
# 4                            1                          1
# ...                        ...                        ...
# 3102                         4                          4
# 3103                         1                          1
# 3104                         4                          4
# 3105                         3                          2
# 3106                         2                          3
#
#      Clinical Care Quartile  Social & Economic Factors Quartile  \
# 0                         1                                   1
# 1                         1                                   1
# 2                         3                                   4
# 3                         2                                   3
# 4                         3                                   1
# ...                     ...                                 ...
# 3102                      3                                   3
# 3103                      1                                   1
# 3104                      3                                   4
# 3105                      4                                   3
# 3106                      2                                   2
#
#      Physical Environment Quartile  Average Quartile  State rank  \
# 0                                4          1.500000           1
# 1                                1          1.000000           1
# 2                                2          3.166667           1
# 3                                2          2.166667           1
# 4                                3          2.000000           1
# ...                            ...               ...         ...
# 3102                             4          3.666667           5
# 3103                             3          1.333333           5
# 3104                             4          3.666667           5
# 3105                             1          2.500000           5
# 3106                             2          2.000000           5
#
#       county modifier  overall county rank  TotalCases  TotalDeaths_y
# 0                 1.0                  2.0        8120          310.0
# 1                 2.0                  3.0        8120          310.0
# 2                -1.0                  0.0        8120          310.0
# 3                 0.0                  1.0        8120          310.0
# 4                 1.0                  2.0        8120          310.0
# ...               ...                  ...         ...            ...
# 3102             -1.0                  4.0         596            7.0
# 3103              1.0                  6.0         596            7.0
# 3104             -1.0                  4.0         596            7.0
# 3105              0.0                  5.0         596            7.0
# 3106              1.0                  6.0         596            7.0
#
# [3107 rows x 15 columns]

# %%
df3.count()
# Out:
# FIPS                                   3107
# State                                  3107
# County                                 3107
# Length of Life Quartile                3107
#  Quality of Life Quartile              3107
#  Health Behaviors Quartile             3107
# Clinical Care Quartile                 3107
#  Social & Economic Factors Quartile    3107
# Physical Environment Quartile          3107
# Average Quartile                       3054
# State rank                             3107
# county modifier                        3054
# overall county rank                    3054
# TotalCases                             3107
# TotalDeaths_y                          3107
# dtype: int64

# %%
df3.drop('County', axis=1, inplace=True)
df3.drop('State', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-b6ac80f920ad> in <module>
# ----> 1 df3.drop('County', axis=1, inplace=True)
#       2 df3.drop('State', axis=1, inplace=True)
#       3 df3 = df3.rename(columns={'TotalDeaths_y ':'TotalDeaths'})
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['County'] not found in axis"

# %%
df3 = df3.rename(columns={'TotalDeaths_y ':'TotalDeaths'})

# %%
df3
# Out:
#        FIPS Length of Life Quartile  Quality of Life Quartile  \
# 0      1001                       1                         1
# 1      1003                       1                         1
# 2      1005                       2                         4
# 3      1007                       3                         1
# 4      1009                       3                         1
# ...     ...                     ...                       ...
# 3102  56037                       4                         4
# 3103  56039                       1                         1
# 3104  56041                       3                         4
# 3105  56043                       2                         3
# 3106  56045                       1                         2
#
#       Health Behaviors Quartile Clinical Care Quartile  \
# 0                             1                      1
# 1                             1                      1
# 2                             4                      3
# 3                             2                      2
# 4                             1                      3
# ...                         ...                    ...
# 3102                          4                      3
# 3103                          1                      1
# 3104                          4                      3
# 3105                          2                      4
# 3106                          3                      2
#
#       Social & Economic Factors Quartile Physical Environment Quartile  \
# 0                                      1                             4
# 1                                      1                             1
# 2                                      4                             2
# 3                                      3                             2
# 4                                      1                             3
# ...                                  ...                           ...
# 3102                                   3                             4
# 3103                                   1                             3
# 3104                                   4                             4
# 3105                                   3                             1
# 3106                                   2                             2
#
#       Average Quartile  State rank  county modifier  overall county rank  \
# 0             1.500000           1              1.0                  2.0
# 1             1.000000           1              2.0                  3.0
# 2             3.166667           1             -1.0                  0.0
# 3             2.166667           1              0.0                  1.0
# 4             2.000000           1              1.0                  2.0
# ...                ...         ...              ...                  ...
# 3102          3.666667           5             -1.0                  4.0
# 3103          1.333333           5              1.0                  6.0
# 3104          3.666667           5             -1.0                  4.0
# 3105          2.500000           5              0.0                  5.0
# 3106          2.000000           5              1.0                  6.0
#
#       TotalCases  TotalDeaths_y
# 0           8120          310.0
# 1           8120          310.0
# 2           8120          310.0
# 3           8120          310.0
# 4           8120          310.0
# ...          ...            ...
# 3102         596            7.0
# 3103         596            7.0
# 3104         596            7.0
# 3105         596            7.0
# 3106         596            7.0
#
# [3054 rows x 13 columns]

# %%
df4
# Out:
#      Unnamed: 0       date    cases  NewCases  deaths
# 0             0  1/21/2020        1         1       0
# 1             1  1/22/2020        1         0       0
# 2             2  1/23/2020        1         0       0
# 3             3  1/24/2020        2         1       0
# 4             4  1/25/2020        3         1       0
# ..          ...        ...      ...       ...     ...
# 99           99  4/29/2020  1039168     26401   55399
# 100         100  4/30/2020  1069561     30393   57570
# 101         101   5/1/2020  1103545     33984   59392
# 102         102   5/2/2020  1133143     29598   61079
# 103         103   5/3/2020  1158656     25513   62140
#
# [104 rows x 5 columns]

# %%
df3 = df3.dropna()

# %%
df3.count()
# Out:
# FIPS                                   3054
# State                                  3054
# County                                 3054
# Length of Life Quartile                3054
#  Quality of Life Quartile              3054
#  Health Behaviors Quartile             3054
# Clinical Care Quartile                 3054
#  Social & Economic Factors Quartile    3054
# Physical Environment Quartile          3054
# Average Quartile                       3054
# State rank                             3054
# county modifier                        3054
# overall county rank                    3054
# TotalCases                             3054
# TotalDeaths_y                          3054
# dtype: int64

# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002D3509055C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002D35067D348>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002D35067D048>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002D350901388>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002D350901D08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\fkokr\.conda\envs\pythondata\lib\site-packages (0.14.1)

# %%
# Disable warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
df10 = df3['TotalCases']

# %%
df10.count()
# Out:
# 3054

# %%
df3.count()
# Out:
# FIPS                                   3054
# Length of Life Quartile                3054
#  Quality of Life Quartile              3054
#  Health Behaviors Quartile             3054
# Clinical Care Quartile                 3054
#  Social & Economic Factors Quartile    3054
# Physical Environment Quartile          3054
# Average Quartile                       3054
# State rank                             3054
# county modifier                        3054
# overall county rank                    3054
# TotalCases                             3054
# TotalDeaths_y                          3054
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X  = df3
y = df10
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
y_train.shape
# Out:
# (2290,)

# %%
X_train.shape
# Out:
# (2290, 13)

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7550218340611353
# Testing Data Score: 0.7513089005235603

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[1,5,10], 'gamma':[0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'gamma': 0.0001}
# 0.9401746724890829
